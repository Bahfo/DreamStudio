# %% [markdown]
# ###### This following documentation is powered by *Jupyter Notebooks*

# %% [markdown]
# <div style="
#     border: 3px solid #1f77b4;
#     padding: 15px;
#     border-radius: 0px;
#     text-align: center;
#     font-size: 40px;
#     font-weight: bold;
#     color: #1f77b4;
#     background-color: #eef6fc;
# ">
#     Getting Started with DreamStudio
# </div>

# %% [markdown]
# *DreamStudio Foundation Represents DreamStudio - A Free Integrated Development Environment That is Cross-Platform, Light-Weight, and Easy to Configure*
#
# Copyright - 2026 DreamStudio - Licensed under ***DreamStudio*** License.

# %% [markdown]
# ###### This documentation is written by Bahaa Nofal - The creator of DreamStudio and his first maintainer. You can become a maintainer for free by following the rules written at section `becoming a maintainer`.

# %% [markdown]
# <div style="
#     border: 3px solid #1f77b4;
#     padding: 15px;
#     border-radius: 0px;
#     text-align: left;
#     font-size: 26px;
#     font-weight: bold;
#     color: #ffffff;
#     background-color: #00589c;
# ">
#     Table of Contents
# </div>

# %% [markdown]
# 1. Getting Started: Installation
# 2. Picking the Right Components for Each Individual
# 3. The Download Manager
# 4. Getting Familiar with DreamStudio Main Window
# 5. Picking up a Project: The Welcome Menu
